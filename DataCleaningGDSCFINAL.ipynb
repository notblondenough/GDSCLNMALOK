# %%
import pandas as pd

# %%
df = pd.read_csv('Data.csv')

# %%
df.head()
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        50 non-null     float64
#  1   Administration   50 non-null     float64
#  2   Marketing Spend  50 non-null     float64
#  3   State            50 non-null     object
#  4   Profit           50 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    73721.615600   121344.639600    211025.097800  112012.639200
# std     45902.256482    28017.802755    122290.310726   40306.180338
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     39936.370000   103730.875000    129300.132500   90138.902500
# 50%     73051.080000   122699.795000    212716.240000  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
# Remove duplicate rows
df = df.drop_duplicates()

# %%
df.isna().sum()
# Out:
# R&D Spend          0
# Administration     0
# Marketing Spend    0
# State              0
# Profit             0
# dtype: int64

# %%
#no data is missing so no need to fillna()

# %%
# replace 0 values with column means
df['R&D Spend'] = df['R&D Spend'].replace(0, df['R&D Spend'].mean())
df['Administration'] = df['Administration'].replace(0, df['Administration'].mean())
df['Marketing Spend'] = df['Marketing Spend'].replace(0, df['Marketing Spend'].mean())

# %%
df
# Out:
#       R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.2000       136897.80      471784.1000    New York  192261.83
# 1   162597.7000       151377.59      443898.5300  California  191792.06
# 2   153441.5100       101145.55      407934.5400     Florida  191050.39
# 3   144372.4100       118671.85      383199.6200    New York  182901.99
# 4   142107.3400        91391.77      366168.4200     Florida  166187.94
# 5   131876.9000        99814.71      362861.3600    New York  156991.12
# 6   134615.4600       147198.87      127716.8200  California  156122.51
# 7   130298.1300       145530.06      323876.6800     Florida  155752.60
# 8   120542.5200       148718.95      311613.2900    New York  152211.77
# 9   123334.8800       108679.17      304981.6200  California  149759.96
# 10  101913.0800       110594.11      229160.9500     Florida  146121.95
# 11  100671.9600        91790.61      249744.5500  California  144259.40
# ...

# %%
df.describe()
# Out:
#            R&D Spend  Administration  Marketing Spend         Profit
# count      50.000000       50.000000        50.000000      50.000000
# mean    76670.480224   121344.639600    223686.603668  112012.639200
# std     43316.419335    28017.802755    109840.387216   40306.180338
# min       542.050000    51283.140000      1903.930000   14681.400000
# 25%     46117.032500   103730.875000    142431.385000   90138.902500
# 50%     73858.087800   122699.795000    212829.953900  107978.190000
# 75%    101602.800000   144842.180000    299469.085000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
#removing outliers in the given data
#using Z-Score Method
#R&D Spend
std=df['R&D Spend'].std()
mean=df['R&D Spend'].mean()
ul=mean+3*std;
ll=mean-3*std;
ul,ll
# Out:
# (206619.73822903878, -53278.77778103876)

# %%
df.loc[(df['R&D Spend']>ul)|(df['R&D Spend']<ll)]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
#all values lies in the range,no outlier detected

# %%
#Administration
std=df['Administration'].std()
mean=df['Administration'].mean()
ul=mean+3*std;
ll=mean-3*std;
df.loc[(df['Administration']>ul)|(df['Administration']<ll)]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
#all values lies in the range,no outlier detected

# %%
#Marketing Spend
std=df['Marketing Spend'].std()
mean=df['Marketing Spend'].mean()
ul=mean+3*std;
ll=mean-3*std;
df.loc[(df['Marketing Spend']>ul)|(df['Marketing Spend']<ll)]
# Out:
# Empty DataFrame
# Columns: [R&D Spend, Administration, Marketing Spend, State, Profit]
# Index: []

# %%
#all values lies in the range,no outlier detected

# %%
#hence data cleaning is done on the given dataset

# %%
df
# Out:
#       R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.2000       136897.80      471784.1000    New York  192261.83
# 1   162597.7000       151377.59      443898.5300  California  191792.06
# 2   153441.5100       101145.55      407934.5400     Florida  191050.39
# 3   144372.4100       118671.85      383199.6200    New York  182901.99
# 4   142107.3400        91391.77      366168.4200     Florida  166187.94
# 5   131876.9000        99814.71      362861.3600    New York  156991.12
# 6   134615.4600       147198.87      127716.8200  California  156122.51
# 7   130298.1300       145530.06      323876.6800     Florida  155752.60
# 8   120542.5200       148718.95      311613.2900    New York  152211.77
# 9   123334.8800       108679.17      304981.6200  California  149759.96
# 10  101913.0800       110594.11      229160.9500     Florida  146121.95
# 11  100671.9600        91790.61      249744.5500  California  144259.40
# ...

# %%
dummies = pd.get_dummies(df["State"])
dummies
# Out:
#     California  Florida  New York
# 0        False    False      True
# 1         True    False     False
# 2        False     True     False
# 3        False    False      True
# 4        False     True     False
# 5        False    False      True
# 6         True    False     False
# 7        False     True     False
# 8        False    False      True
# 9         True    False     False
# 10       False     True     False
# 11        True    False     False
# 12       False     True     False
# 13        True    False     False
# 14       False     True     False
# 15       False    False      True
# 16        True    False     False
# 17       False    False      True
# 18       False     True     False
# 19       False    False      True
# 20        True    False     False
# 21       False    False      True
# 22       False     True     False
# 23       False     True     False
# 24       False    False      True
# 25        True    False     False
# ...

# %%
dummies = dummies.astype(int)
df = pd.concat([df, dummies], axis=1)
df
# Out:
#       R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.2000       136897.80      471784.1000    New York  192261.83  \
# 1   162597.7000       151377.59      443898.5300  California  191792.06
# 2   153441.5100       101145.55      407934.5400     Florida  191050.39
# 3   144372.4100       118671.85      383199.6200    New York  182901.99
# 4   142107.3400        91391.77      366168.4200     Florida  166187.94
# 5   131876.9000        99814.71      362861.3600    New York  156991.12
# 6   134615.4600       147198.87      127716.8200  California  156122.51
# 7   130298.1300       145530.06      323876.6800     Florida  155752.60
# 8   120542.5200       148718.95      311613.2900    New York  152211.77
# 9   123334.8800       108679.17      304981.6200  California  149759.96
# 10  101913.0800       110594.11      229160.9500     Florida  146121.95
# 11  100671.9600        91790.61      249744.5500  California  144259.40
# ...

# %%
# Drop the "State" column
df = df.drop("State", axis=1)

# Rearrange the "Price" column to the last position
price_column = df.pop("Profit")
df["Profit"] = price_column

# %%
df
# Out:
#       R&D Spend  Administration  Marketing Spend  California  Florida
# 0   165349.2000       136897.80      471784.1000           0        0  \
# 1   162597.7000       151377.59      443898.5300           1        0
# 2   153441.5100       101145.55      407934.5400           0        1
# 3   144372.4100       118671.85      383199.6200           0        0
# 4   142107.3400        91391.77      366168.4200           0        1
# 5   131876.9000        99814.71      362861.3600           0        0
# 6   134615.4600       147198.87      127716.8200           1        0
# 7   130298.1300       145530.06      323876.6800           0        1
# 8   120542.5200       148718.95      311613.2900           0        0
# 9   123334.8800       108679.17      304981.6200           1        0
# 10  101913.0800       110594.11      229160.9500           0        1
# 11  100671.9600        91790.61      249744.5500           1        0
# ...

# %%
df.to_csv('Clean_Data.csv', index=False)
